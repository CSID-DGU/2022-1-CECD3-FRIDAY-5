# %%
emoji_table = {"😀":"웃음", "😄":"함박웃음", "😊":"미소", "🥳":"축하", "🤗":"환영", 
               "🤩":"설렘", "😍":"하트", "🤔":"고민중", "😐":"노잼", "😝":"장난",
              "🤯":"멘탈붕괴", "🤒":"아프다", "🤢":"구역질", "😱":"경악", "🤬":"화가 나",
              "❤":"사랑", "💖":"사랑", "👋":"안녕", "🙏":"미안", "😙":"신남",
              "😘":"사랑스러워", "😂":"감격", "😉":"윙크", "🙂":"평온한 미소", "🤣":"웃겨"}

# %%
import requests
import re
from bs4 import BeautifulSoup
from urllib.parse import quote
from kiwipiepy import Kiwi
import pandas as pd

separators = ".", "!","?","\n","\t","/n","/t"
# urllib.parse.quote()는 아스키코드 형식이 아닌 글자를 URL 인코딩 시켜줍니다.


temporary_list_for_csv = []
line_num = 0

# 문장 단위로 자르기
def split_sentence(blog_texts):
    global temporary_list_for_csv
    global line_num
    
    kiwi = Kiwi()

    for line in kiwi.split_into_sents(blog_texts):
        if len(line.text) < 10:
            continue
        line_num += 1
        temporary_list_for_csv.append([line_num, remove_zero_width_space(line.text)])
    return

# 텍스트 전처리
# 지금은 이모티콘 치환만
def preprocess_sentence_kr(text):
    text = emoji_substitution(text)

    return text

# zero width space 제거 
def remove_zero_width_space(w):
    w = w.strip()
    w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w) # \n도 공백으로 대체해줌
    w = w.strip()
    return w

# 이모티콘 치환
def emoji_substitution(blog_texts):
    for key in emoji_table.keys():
        if key in blog_texts:
            blog_texts = blog_texts.replace(key,emoji_table[key])
    
    return blog_texts
    

# 여러 구분자 사용 가능하게 해주는 함수
def custom_split(sepr_list, str_to_split):
    # create regular expression dynamically
    regular_exp = '|'.join(map(re.escape, sepr_list))
    return re.split(regular_exp, str_to_split)

# iframe 제거 후 blog.naver.com 붙이기
def delete_iframe(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    src_url = "https://blog.naver.com/" + soup.iframe["src"]
    
    return src_url

# 네이버블로그 본문 스크래핑
def text_scraping(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    if soup.find("div", attrs={"class":"se-main-container"}):
        text = soup.find("div", attrs={"class":"se-main-container"}).get_text(' ',strip=True)
        #text = text.replace("\n","") #공백 제거
        return text

    elif soup.find("div", attrs={"id":"postViewArea"}):
        text = soup.find("div", attrs={"id":"postViewArea"}).get_text(' ',strip=True)
        #text = text.replace("\n","") 
        return text
    else:
        return "네이버 블로그는 맞지만, 확인불가"

#오늘일기 이벤트 진행기간
# dates=["0501","0502","0503","0504","0505","0506","0507","0508","0509","0510","0511","0512","0513","0514","0515","0516","0517","0518","0519","0520","0521","0522","0523","0524","0525","0526","0527","0528","0529","0530","0531","0601","0602","0603","0604","0605","0606","0607","0608","0609","0610","0611","0612","0613","0614"]
dates=["0501"]

f = open("crawling_result.txt", 'w', encoding='utf-8')

print("Crawling Start ...")

for date in dates:
    url = "https://search.naver.com/search.naver?where=view&query=%EC%98%A4%EB%8A%98%EC%9D%BC%EA%B8%B0%20%EB%B8%94%EC%B1%8C&sm=tab_opt&nso=so%3Ar%2Cp%3Afrom2021"+date+"to2021"+date+"%2Ca%3Aall&mode=normal&main_q=&st_coll=&topic_r_cat=" 

    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    posts = soup.find_all("li", attrs={"class":"bx _svp_item"})
    
    for post in posts:
        print("-"*50)
        post_title = post.find("a", attrs={"class":"api_txt_lines total_tit _cross_trigger"}).get_text()
        print("제목 :",post_title)
        post_link = post.find("a", attrs={"class":"api_txt_lines total_tit _cross_trigger"})['href']
        print("link :", post_link)


        blog_p = re.compile("blog.naver.com")
        blog_m = blog_p.search(post_link)

        if blog_m:
            blog_texts=text_scraping(delete_iframe(post_link)) # 본문 뽑아옴
            blog_texts = preprocess_sentence_kr(blog_texts) # 텍스트 전처리 
            
            # 문장단위로 분리
            split_sentence(blog_texts)
            
            blog_texts_split=custom_split(separators, blog_texts)
            print("<본문>")
            for i in blog_texts_split:
                f.write(i+"\n")
            
            #print(blog_texts)
            """
            for blog_text in blog_texts:
                print(blog_text)
            """
        else:
            print("카페 및 포스트 : 확인 불가")

        print("-"*50)
f.close()

df = pd.DataFrame(temporary_list_for_csv, columns=['id', 'sentence'])
df.to_csv('crawling_naver_blog.csv', index=False, encoding='cp949') 

print("Crawling Done ...")
# Out:
# Crawling Start ...
# --------------------------------------------------
# 제목 : 5/1 #오늘일기 #블챌
# link : https://blog.naver.com/gonirao/222331174309
# <본문>
# --------------------------------------------------
# --------------------------------------------------
# 제목 : 매일매일 챌린지 #오늘일기#블챌
# link : https://blog.naver.com/ehee50271/222331092751
# <본문>
# --------------------------------------------------
# --------------------------------------------------
# 제목 : 오늘일기 전선생 1일 1포스팅의 습관 블챌 시작합니다
# link : https://blog.naver.com/jmbcook/222330118972
# <본문>
# --------------------------------------------------
# --------------------------------------------------
# 제목 : 0501 #오늘일기 1일차 #블챌
# link : https://blog.naver.com/slyj311/222331029146
# <본문>
# --------------------------------------------------
# --------------------------------------------------
# 제목 : 5월 1일의 일상 #오늘일기 #블챌
# link : https://blog.naver.com/rano_0114/222331496227
# <본문>
# --------------------------------------------------
# ...

# %% [markdown]
# #### csv 파일 결과
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 이슈
# -  '.'으로만 이루어진 문장
# -  너무 짧은 문장

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 일단 10글자 안 넘는 문장은 csv에 저장 안하게 했는데 완벽한 해결책은 아님
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -  인용의 경우 문장 제대로 분리 안됨
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Jupyter Notebook에서 KoNLPy 사용
# ---

# %% [markdown]
# KoNLPy: 한국어 자연어 처리를 위한 파이썬 라이브러리
# https://hi-datalab.tistory.com/15

# %%
from konlpy.tag import *
from eunjeon import Mecab 

sentence = "연세우유는 저렴해서 사봤습니다"
hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
mecab = Mecab()
okt = Okt()

print("== hannanum 형태소 분석 결과 ==")
print(hannanum.pos(sentence))

print("\n== kkma 형태소 분석 결과 ==")
print(kkma.pos(sentence))

print("\n== komoran 형태소 분석 결과 ==")
print(komoran.pos(sentence))

print("\n== mecab 형태소 분석 결과 ==")
print(mecab.pos(sentence))

print("\n== okt 형태소 분석 결과 ==")
print(okt.pos(sentence))
# Out:
# == hannanum 형태소 분석 결과 ==
# [('연세우유', 'N'), ('는', 'J'), ('저렴해', 'N'), ('서', 'J'), ('사', 'P'), ('아', 'E'), ('보', 'P'), ('아ㅂ니다', 'E')]
#
# == kkma 형태소 분석 결과 ==
# [('연세', 'NNG'), ('우유', 'NNG'), ('는', 'JX'), ('저렴', 'XR'), ('하', 'XSA'), ('어서', 'ECD'), ('사', 'VV'), ('아', 'ECS'), ('보', 'VXV'), ('았', 'EPT'), ('습니다', 'EFN')]
#
# == komoran 형태소 분석 결과 ==
# [('연세', 'NNP'), ('우유', 'NNP'), ('는', 'JX'), ('저렴', 'XR'), ('하', 'XSA'), ('아서', 'EC'), ('사', 'VV'), ('아', 'EC'), ('보', 'VX'), ('았', 'EP'), ('습니다', 'EC')]
#
# == mecab 형태소 분석 결과 ==
# [('연세', 'NNG'), ('우유', 'NNG'), ('는', 'JX'), ('저렴', 'XR'), ('해서', 'XSA+EC'), ('사', 'VV+EC'), ('봤', 'VX+EP'), ('습니다', 'EF')]
#
# == okt 형태소 분석 결과 ==
# [('연', 'Modifier'), ('세', 'Modifier'), ('우유', 'Noun'), ('는', 'Josa'), ('저렴해서', 'Adjective'), ('사봤습니다', 'Verb')]

# %% [markdown]
# ### 라이브러리별 품사 태그

# %%
import pandas as pd

tagsets = pd.DataFrame()
pd.set_option('display.max_rows', None)
N = 67
tagsets["Hannanum-기호"] = list(hannanum.tagset.keys()) + list("*" * (N - len(hannanum.tagset)))
tagsets["Hannanum-품사"] = list(hannanum.tagset.values()) + list("*" * (N - len(hannanum.tagset)))
tagsets["Kkma-기호"] = list(kkma.tagset.keys()) + list("*" * (N - len(kkma.tagset)))
tagsets["Kkma-품사"] = list(kkma.tagset.values()) + list("*" * (N - len(kkma.tagset)))
tagsets["Komoran-기호"] = list(komoran.tagset.keys()) + list("*" * (N - len(komoran.tagset)))
tagsets["Komoran-품사"] = list(komoran.tagset.values()) + list("*" * (N - len(komoran.tagset)))
tagsets["Mecab-기호"] = list(mecab.tagset.keys()) + list("*" * (N - len(mecab.tagset)))
tagsets["Mecab-품사"] = list(mecab.tagset.values()) + list("*" * (N - len(mecab.tagset)))
tagsets["OKT-기호"] = list(okt.tagset.keys()) + list("*" * (N - len(okt.tagset)))
tagsets["OKT-품사"] = list(okt.tagset.values()) + list("*" * (N - len(okt.tagset)))
tagsets
# Out:
#    Hannanum-기호 Hannanum-품사 Kkma-기호              Kkma-품사 Komoran-기호  \
# 0            E          어미      EC                연결 어미         EC
# 1           EC       연결 어미     ECD            의존적 연결 어미         EF
# 2           EF       종결 어미     ECE             대등 연결 어미         EP
# 3           EP       선어말어미     ECS            보조적 연결 어미        ETM
# 4           ET       전성 어미      EF                종결 어미        ETN
# 5            F         외국어     EFA            청유형 종결 어미         IC
# 6            I         독립언     EFI            감탄형 종결 어미         JC
# 7           II         감탄사     EFN            평서형 종결 어미        JKB
# 8            J         관계언     EFO            명령형 종결 어미        JKC
# 9           JC         격조사     EFQ            의문형 종결 어미        JKG
# 10          JP      서술격 조사     EFR            존칭형 종결 어미        JKO
# 11          JX         보조사      EP               선어말 어미        JKQ
# 12           M         수식언     EPH            존칭 선어말 어미        JKS
# ...

# %% [markdown]
# 위에서 예시 문장인 "연세우유는 저렴해서 사봤습니다"를 종결어미로 마무리한 라이브러리는 Kkma와 Mecab

# %%
sentence = "어제 밤 샘"

print("== hannanum 형태소 분석 결과 ==")
print(hannanum.pos(sentence))

print("\n== kkma 형태소 분석 결과 ==")
print(kkma.pos(sentence))

print("\n== komoran 형태소 분석 결과 ==")
print(komoran.pos(sentence))

print("\n== mecab 형태소 분석 결과 ==")
print(mecab.pos(sentence))

print("\n== okt 형태소 분석 결과 ==")
print(okt.pos(sentence))
# Out:
# == hannanum 형태소 분석 결과 ==
# [('어제', 'N'), ('밤', 'N'), ('샘', 'N')]
#
# == kkma 형태소 분석 결과 ==
# [('어제', 'NNG'), ('밤', 'NNG'), ('샘', 'NNG')]
#
# == komoran 형태소 분석 결과 ==
# [('어제', 'MAG'), ('밤', 'NNG'), ('샘', 'NNP')]
#
# == mecab 형태소 분석 결과 ==
# [('어제', 'MAG'), ('밤', 'NNG'), ('샘', 'NNG')]
#
# == okt 형태소 분석 결과 ==
# [('어제', 'Noun'), ('밤', 'Noun'), ('샘', 'Noun')]

# %% [markdown]
# 인터넷에서 자주 사용되는 말투인 '~함'으로 넣어본 결과, 마지막 형태소가 명사로 분석됨.

# %%
sentence = " 새벽에 일어나니 곤히 자고 있던 하비니  공동현관 비번이 없는 구린 아파트에 사는 전 새벽배송 받으러 밖으로 나갑니다 ​ ​ 이러고 가요 ​ ​ 진상이지만 공동현관 앞에 놓아달라고 합니다 사람들이 많이 오가는 시간이 되기 전에 항시 6시즈음에 찾으러가는 나는야 부지런한 워킹맘 ​ ​ 이것 때문에 미니 카트도 구입했습니다 돈 아깝지 않아요 ​ ​ #마켓컬리 #장바구니 상온식품으로는 항시 시키는 컬리 통밀식빵 그래놀라하우스 오리지날의 품절로 카카오 뭐시깽이를 시켰습니다 맛있더군요 모두에게 추천하고 다닌 오뗄두스 사브레 (얼그레이) ​ ​ 냉동식품으로는 숭의가든 한돈 목살 양념구이 세일할 때 사야 이득이지만 세일을 도통 안해서 정가구매 그리고 석관동 떡볶이 유툽잇님 샤나님의 단골 메뉴로 컬리에 있길래 저도 시켜보았어요 ​ ​ 냉장식품 너무 많네요 ㅋㅋㅋ 훈제오리와 (이렇게 작을 줄 몰랐음) 연세우유는 처음 시켜봤어요 연세우유는 저렴해서 사봤습니다 그 컬리 전용 보라색 우유로 요거트를 만들었을 때 무척 맛있었기 때문에 또 시켜볼까 했지만 연세우유가 처넌이나 저렴해서 궁금해서 구매 ​ ​ 쿠팡후레시 시키는 일 거의 없지만 (아마 결혼 후 두번째) 컬리에서 사먹었던 낙지젓갈이 너무 맛있는데 가성비가 후져서 ㅋ 쿠팡에 후기가 4천개가 넘는 낙지젓을 구매해봤어요 사고보니 중국oem이네요 우수수입업소인증은 받아서 그래도 안심하고 먹어보겠어요 그거 받기 나름 까다롭거든여 (식품업계 종사중) ​ ​ 꿀 퍼먹는 큰 딸에게 애비님이 보내주신 꿀 王꿀 너무나 강려크한 꿀 패키징에 웃었네요 ​ ​ 너무 거대해서 소분해줍니다 ​ ​ 웩이었나"
print(sentence)
# 문단에서 종결어미 뽑아보기 
for unit in kkma.pos(sentence):
    if(unit[1]=="EF" or unit[1]=="EFA" or unit[1]=="EFI" or unit[1]=="EFN" or unit[1]=="EFO" or unit[1]=="EFQ" or unit[1]=="EFR"):
        print(unit)
# Out:
#  새벽에 일어나니 곤히 자고 있던 하비니  공동현관 비번이 없는 구린 아파트에 사는 전 새벽배송 받으러 밖으로 나갑니다 ​ ​ 이러고 가요 ​ ​ 진상이지만 공동현관 앞에 놓아달라고 합니다 사람들이 많이 오가는 시간이 되기 전에 항시 6시즈음에 찾으러가는 나는야 부지런한 워킹맘 ​ ​ 이것 때문에 미니 카트도 구입했습니다 돈 아깝지 않아요 ​ ​ #마켓컬리 #장바구니 상온식품으로는 항시 시키는 컬리 통밀식빵 그래놀라하우스 오리지날의 품절로 카카오 뭐시깽이를 시켰습니다 맛있더군요 모두에게 추천하고 다닌 오뗄두스 사브레 (얼그레이) ​ ​ 냉동식품으로는 숭의가든 한돈 목살 양념구이 세일할 때 사야 이득이지만 세일을 도통 안해서 정가구매 그리고 석관동 떡볶이 유툽잇님 샤나님의 단골 메뉴로 컬리에 있길래 저도 시켜보았어요 ​ ​ 냉장식품 너무 많네요 ㅋㅋㅋ 훈제오리와 (이렇게 작을 줄 몰랐음) 연세우유는 처음 시켜봤어요 연세우유는 저렴해서 사봤습니다 그 컬리 전용 보라색 우유로 요거트를 만들었을 때 무척 맛있었기 때문에 또 시켜볼까 했지만 연세우유가 처넌이나 저렴해서 궁금해서 구매 ​ ​ 쿠팡후레시 시키는 일 거의 없지만 (아마 결혼 후 두번째) 컬리에서 사먹었던 낙지젓갈이 너무 맛있는데 가성비가 후져서 ㅋ 쿠팡에 후기가 4천개가 넘는 낙지젓을 구매해봤어요 사고보니 중국oem이네요 우수수입업소인증은 받아서 그래도 안심하고 먹어보겠어요 그거 받기 나름 까다롭거든여 (식품업계 종사중) ​ ​ 꿀 퍼먹는 큰 딸에게 애비님이 보내주신 꿀 王꿀 너무나 강려크한 꿀 패키징에 웃었네요 ​ ​ 너무 거대해서 소분해줍니다 ​ ​ 웩이었나
# ('던', 'EFQ')
# ('ㅂ니다', 'EFN')
# ('ㅂ니다', 'EFN')
# ('습니다', 'EFN')
# ('아요', 'EFN')
# ('습니다', 'EFN')
# ('더군요', 'EFI')
# ('어요', 'EFN')
# ('네요', 'EFN')
# ('어요', 'EFN')
# ('습니다', 'EFN')
# ...

# %% [markdown]
# ### 한국어 문장 분리 기능 제공 라이브러리 Kiwi
# ---
# Kiwi github
# https://github.com/bab2min/kiwipiepy
#
# Package kiwipiepy Documentation
# https://bab2min.github.io/kiwipiepy/v0.12.0/kr/
#
# 엄청 좋은 걸 발견했다
# 문장 분류는 걱정 안해도 될 것 같다.

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()


print(type(kiwi.split_into_sents(sentence)))
for line in kiwi.split_into_sents(sentence):
    print(line.text + "//")
# Out:
# <class 'list'>
# 새벽에 일어나니 곤히 자고 있던 하비니 🙂 ​ ​ 공동현관 비번이 없는 구린 아파트에 사는 전 새벽배송 받으러 밖으로 나갑니다//
# 이러고 가요//
# 진상이지만 공동현관 앞에 놓아달라고 합니다//
# 사람들이 많이 오가는 시간이 되기 전에 항시 6시즈음에 찾으러가는 나는야 부지런한 워킹맘 ​ ​ 이것 때문에 미니 카트도 구입했습니다//
# 돈 아깝지 않아요//
# #마켓컬리 #장바구니 상온식품으로는 항시 시키는 컬리 통밀식빵 그래놀라하우스 오리지날의 품절로 카카오 뭐시깽이를 시켰습니다//
# 맛있더군요 모두에게 추천하고 다닌 오뗄두스 사브레 (얼그레이) ​ ​ 냉동식품으로는 숭의가든 한돈 목살 양념구이 세일할 때 사야 이득이지만 세일을 도통 안해서 정가구매 그리고 석관동 떡볶이 유툽잇님 샤나님의 단골 메뉴로 컬리에 있길래 저도 시켜보았어요 ​ ​ 냉장식품 너무 많네요 ㅋㅋㅋ//
# 훈제오리와 (이렇게 작을 줄 몰랐음) 연세우유는 처음 시켜봤어요//
# 연세우유는 저렴해서 사봤습니다//
# 그 컬리 전용 보라색 우유로 요거트를 만들었을 때 무척 맛있었기 때문에 또 시켜볼까 했지만 연세우유가 처넌이나 저렴해서 궁금해서 구매 ​ ​ 쿠팡후레시 시키는 일 거의 없지만 (아마 결혼 후 두번째) 컬리에서 사먹었던 낙지젓갈이 너무 맛있는데//
# 가성비가 후져서 ㅋ 쿠팡에 후기가 4천개가 넘는 낙지젓을 구매해봤어요//
# 사고보니 중국oem이네요 우수수입업소인증은 받아서 그래도 안심하고 먹어보겠어요//
# 그거 받기 나름 까다롭거든여 (식품업계 종사중) ​ ​ 꿀 퍼먹는 큰 딸에게 애비님이 보내주신 꿀 王꿀 너무나 강려크한 꿀 패키징에 웃었네요//
# 너무 거대해서 소분해줍니다//
# 웩이었나//

# %%
sentence = "😂😍💖"
print(emoji_substitution(sentence))
# Out:
# 감격하트사랑
